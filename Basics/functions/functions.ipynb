# %% [markdown]
# **Functions**
# Functions are programs that perform a specific task, they can be seen as block of codes that serves as solutions to a coding challenge. Functions help in code recycling as codes serve the purpose of reusabaility.
#
# **Types of Functions**
# There are two types of functions basically.
# - Implicite functions
#   Implicite functions are functions that exist primarily in python without externally creating it. These type of functions are built-in and cannot be used to name variables.
#
#   Examples are;
#   print()
#   len()
#   etc.
#
# - Explicite Functions
#   Like the name, explicite functions are functions that are created by the programmer.
#   It involves defining the function, using a doc string to explain the intent of the function, the block of code, and the function call, which is the same as the function name with parentheses.
#
#
# In explicite functions, there are terms that are commonly used.
# - Arguments.
#   Arguments are values that are passed to the functions as inputs.
#   They are usually passed to the function call.
#
# - Return
#   The return statement returns the value as output, depending on the scenario. If the funtion call is not printed, it returns what is stored in the funtion but it doesn't display it. If it's printed it returns and displays the output to the user.
#
# - def keyword
#   Functions usually start with the def keyword, which is short for define.
#
# - Parameters
#   parameters are variables that represent the values of which the functions interact with when called.
#   Parameters are variables that contain arguments.

# %%
def greet():  # Function definition
    """write a basic script that greets the user.
    This is a doc string and it explains the intent
    of the code."""
    return "Good morning! It's great to have you around."  # Function body.

print(greet())  # Function call
# Out:
# Good morning! It's great to have you around.

# %%
import random as rn

def number_guess():
    """Guess from a random number."""
    play = True

    while play:
        raw_input = input("Type in 3 numbers separated by commas or (q to quit): ")

        # Exit code
        if raw_input.lower() == "q":
            print("Exiting...")
            break

        # Normalize input
        cleaned_input = raw_input.replace(" ", "")
        comma_split = cleaned_input.split(",")

        # Validation
        if len(comma_split) != 3:
            print("Please enter exactly three numbers.")
            continue

        if not all(dgt.isdigit() for dgt in comma_split):
            print("Only numbers are allowed.")
            continue

        # User input → [[1], [2], [3]]
        list_container = [[int(dgt)] for dgt in comma_split]

        # Random number → [n]
        random_check = [rn.randint(1, 10)]

        # Comparison (list-to-list)
        if random_check in list_container:
            print("You guessed correctly!")
        else:
            print("Wrong guess.")

        print(list_container, "\n=>\n", random_check)

number_guess()
# Out:
# Invalid input!
# [[1], [2], [3]]
# =>
#  1
# Exiting...
# Please enter exactly three numbers.

# %%
import random as rn


def number_guess():
    """Guess from a random number."""
    play = True

    while play:
        raw_input = input("Type in 3 numbers seperated by commas or (q to quit): ")
        random_check = [rn.randint(1, 10)]
        

        # Exit code
        if raw_input.lower() == "q":
            print("Exiting...")
            play = False

        # Conditionals
        cleaned_input = raw_input.replace(" ", "")
        comma_split = cleaned_input.split(",")
        more_than_3_entries = len(comma_split) != 3

        # Validation
        if more_than_3_entries:
            print("Please enter exactly three numbers.")
            continue

        if not all(dgt.isdigit() for dgt in comma_split):
            print("Only numbers are allowed,")
            continue
       
        list_container = [[int(dgt)] for dgt in comma_split]
        match = [x for x in list_container if x == random_check]
        if random_check in list_container:
            print("You guessed correctly")
            print(list_container,"\n", match "\n=>\n", random_check )
        else:
            print("Invalid input!")
            print(list_container, "\n=>\n", random_check )



number_guess()
# Out:
# Invalid input!
# [[1], [2], [3]]
# =>
#  [9]
# You guessed correctly
# [[1], [5], [7]]
# =>
#  [5]
# Exiting...
# Please enter exactly three numbers.

# %%
import random as rn

def number_guess():
    """Guess from a random number."""
    while True:
        raw_input = input("Type in 3 numbers separated by commas or (q to quit): ")

        if raw_input.lower() == "q":
            print("Exiting...")
            break

        # Conditionals
        cleaned_input = raw_input.replace(" ", "")
        comma_split = cleaned_input.split(",")

        # Validation
        if len(comma_split) != 3:
            print("Please enter exactly three numbers.")
            continue

        if not all(dgt.isdigit() for dgt in comma_split):
            print("Only numbers are allowed.")
            continue

        # User numbers as [[1], [2], [3]]
        list_container = [[int(dgt)] for dgt in comma_split]

        # Random number as [n]
        random_check = [rn.randint(1, 10)]

        # Matching sublists
        match = [x for x in list_container if x == random_check]

        if match:
            print("You guessed correctly!")
        else:
            print("Wrong guess!")

        print("Your numbers:", list_container)
        print("Matches:", match)
        print("Random number:", random_check, "\n")

number_guess()
# Out:
# You guessed correctly!
# Your numbers: [[1], [2], [3]]
# Matches: [[2]]
# Random number: [2]
#
# Wrong guess!
# Your numbers: [[4], [5], [6]]
# Matches: []
# Random number: [7]
#
# Wrong guess!
# Your numbers: [[5], [6], [8]]
# Matches: []
# Random number: [3]
#
# Wrong guess!
# Your numbers: [[5], [6], [89]]
# Matches: []
# Random number: [1]
#
# Wrong guess!
# Your numbers: [[2], [4], [7]]
# Matches: []
# Random number: [3]
#
# Please enter exactly three numbers.
# Please enter exactly three numbers.
# Wrong guess!
# Your numbers: [[3], [5], [6]]
# Matches: []
# Random number: [2]
#
# Wrong guess!
# Your numbers: [[2], [3], [4]]
# Matches: []
# Random number: [6]
#
# You guessed correctly!
# Your numbers: [[1], [2], [4]]
# Matches: [[4]]
# Random number: [4]
#
# Exiting...

# %% [markdown]
# The return keyword hands data back to the caller.
# - It ends the function
# - Data returned can be stored in a variable
# - Functions without return, return none

# %%
def add(a, b):
    addition = a + b
    return addition, a, b

num1 = 12
num2= 18
output = add(num1, num2)
print("The output is displayed in a tuple.")
print(output)
# Out:
# The output is displayed in a tuple.
# (30, 12, 18)

# %% [markdown]
# Scope in python
# Scope determines the availability of variables in python. For instance, how one can access a variable in a code block: whether it is global or not.
#
# Python follows this rule to access variables.
# LEGB
# L -> local (These are variables inside a function.)
#
# E -> Enclosing (Variables inside a nested function)
#
# G -> Global (These are variables that are assigned at the top of the file.)
#
# B -> Built-in (These are python's own names.)

# %%
# Local variables
def greet():
    message = "hello"
    print(message)

greet()  
print("The variable is immediately destroyed when the functions ends.")
# Out:
# hello

# %%
# Global variable.
# These are variables assigned outside the function.

data = [1, 2, 3, 4, 5]
print(f"Before: {data}")

def sorted_list():
    global data
    data.sort(reverse=True)
    # print(data)
    print(f"After: {data}")

sorted_list()

# Functions can read global variables freely.
# Out:
# Before: [1, 2, 3, 4, 5]
# After: [5, 4, 3, 2, 1]

# %%
# Enclosing scope
def outer():
    x = "outside"

    def inner():
        print(x)


    inner()


outer()
# Out:
# outside

# %%
# Enclosing method can be modified by using the non - local method.
def outer():
    count = 0

    def inner():
        nonlocal count  # variables in the nearest enclosing function
        count += 1
        print(count)

    inner()

outer()
# Out:
# 1
